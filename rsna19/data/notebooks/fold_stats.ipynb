# %% [markdown]
# <h2>Class statistics for every fold</h2>

# %%
import pandas as pd

# %%
DATASETS_ROOT = "../../datasets/"

# %%
df = pd.read_csv(DATASETS_ROOT + '5fold.csv')

# %%
folds_grouped = df.groupby('fold')
folds_grouped.sum()
# Out:
#           any  epidural  intraparenchymal  intraventricular  subarachnoid  \
# fold
# 0     19507.0     569.0            6674.0            4782.0        5966.0
# 1     19077.0     363.0            6495.0            4777.0        6415.0
# 2     18838.0     551.0            6117.0            4534.0        6302.0
# 3     20058.0     704.0            6811.0            4884.0        6658.0
# 4     19623.0     574.0            6467.0            4789.0        6781.0
#
#       subdural
# fold
# 0       8549.0
# 1       8579.0
# 2       8054.0
# 3       8591.0
# 4       8723.0

# %%
df = pd.read_csv(DATASETS_ROOT + '5fold3D.csv')
folds_grouped = df.groupby('fold')
folds_grouped.sum()
# Out:
#          any  epidural  intraparenchymal  intraventricular  subarachnoid  \
# fold
# 0     1595.0      65.0             961.0             633.0         695.0
# 1     1555.0      45.0             961.0             663.0         688.0
# 2     1535.0      57.0             903.0             643.0         675.0
# 3     1683.0      88.0            1010.0             686.0         748.0
# 4     1635.0      58.0             961.0             688.0         743.0
#
#       subdural
# fold
# 0        692.0
# 1        692.0
# 2        643.0
# 3        722.0
# 4        693.0
